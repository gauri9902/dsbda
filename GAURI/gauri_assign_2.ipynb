# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
df=pd.read_csv('IMDBTopMovies.csv')

# %%
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df2=df.copy()

# %%
df2
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
mean=df2['rating'].mean()

# %%
mean
# Out:
# 8.3072

# %%
median=df2['rating'].median()

# %%
median
# Out:
# 8.2

# %%
mode=df2['rating'].mode()

# %%
mode
# Out:
# 0    8.1
# Name: rating, dtype: float64

# %%
mode=df2.mode().values[0]
mode
# Out:
# array([1, '12 Angry Men', 1995.0, 8.1, 'Drama', 'R', '2h 10m',
#        '"As far back as I can remember, I\'ve always wanted to be a gangster." -- Henry Hill, Brooklyn, N.Y. 1955.',
#        'Not Available', 'Not Available',
#        'Aamir Khan,Madhavan,Mona Singh,Sharman Joshi,Kareena Kapoor,Boman Irani,Omi Vaidya,Olivier Lafont,Rahul Kumar,Parikshit Sahni,Farida Dadi,Amardeep Jha,Mukund Bhatt,Chaitali Bose,Jaaved Jaaferi,Jayant Kripalani,Arun Bali,Shoaib Ahmed',
#        'Akira Kurosawa', 'Charles Chaplin'], dtype=object)

# %%
df2.isnull()
# Out:
#       rank   name   year  rating  genre  certificate  run_time  tagline  \
# 0    False  False  False   False  False        False     False    False
# 1    False  False  False   False  False        False     False    False
# 2    False  False  False   False  False        False     False    False
# 3    False  False  False   False  False        False     False    False
# 4    False  False  False   False  False        False     False    False
# ..     ...    ...    ...     ...    ...          ...       ...      ...
# 245  False  False  False   False  False        False     False    False
# 246  False  False  False   False  False        False     False    False
# 247  False  False  False   False  False        False     False    False
# 248  False  False  False   False  False        False     False    False
# 249  False  False  False   False  False        False     False    False
#
#      budget  box_office  casts  directors  writers
# 0     False       False  False      False    False
# ...

# %%
num_columns = [col for col in df2.columns if (df2[col].dtype == 'float' or df2[col].dtype =='int64')]

# %%
num_columns
# Out:
# ['rank', 'year', 'rating']

# %%
for i in num_columns:
    df2[i].fillna(round(mean),inplace=True)
df2
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
print(df2['box_office'].dtype)
# Out:
# object

# %%
str_columns=[col for col in df2.columns if(df2[col].dtype=='object')]

# %%
str_columns
# Out:
# ['name',
#  'genre',
#  'certificate',
#  'run_time',
#  'tagline',
#  'budget',
#  'box_office',
#  'casts',
#  'directors',
#  'writers']

# %%
plt.hist(df2['budget'])
plt.xlabel('budget')
plt.ylabel('frequency')
plt.title('Histogram or Budget')
# Out:
# Text(0.5, 1.0, 'Histogram or Budget')

# %%
plt.scatter(df2['budget'],df2['box_office'])

# %%
plt.plot(df2['budget'],df2['box_office'])
