# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
dataset=sns.load_dataset('titanic')

# %%
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
dataset.shape
# Out:
# (891, 15)

# %%
print("Number of people survived: ",dataset["survived"].value_counts()[1])
print("Number of people not survived: ",dataset["survived"].value_counts()[0])
# Out:
# Number of people survived:  342
# Number of people not survived:  549

# %%
sns.countplot(data=dataset,x='survived')
plt.show()

# %%
sns.countplot(data=dataset,x='fare')
plt.show()

# %%
sns.histplot(dataset['fare'])
plt.show()

# %%
sns.boxplot(data=dataset, x='age', y='sex', hue='survived')
plt.show()

# %%
sns.pairplot(dataset)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/numpy/lib/histograms.py:351, in _unsigned_subtract(a, b)
#     350 try:
# --> 351     dt = signed_to_unsigned[dt.type]
#     352 except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 sns.pairplot(dataset)
#       2 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
# ...
